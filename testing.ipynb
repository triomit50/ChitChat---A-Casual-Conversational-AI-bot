# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.1-8b-instant")
llm.invoke("LangSmith tracing sanity check")
# Out:
# AIMessage(content="I'm not familiar with LangSmith. It seems like it might be a project or tool that I am not aware of. Can you please provide more information about LangSmith, such as its purpose and any relevant details? This will help me perform a more accurate sanity check.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 40, 'total_tokens': 96, 'completion_time': 0.134898774, 'completion_tokens_details': None, 'prompt_time': 0.001841004, 'prompt_tokens_details': None, 'queue_time': 0.052711526, 'total_time': 0.136739778}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b6adc-31ab-7701-9d20-ac5c046563c2-0', usage_metadata={'input_tokens': 40, 'output_tokens': 56, 'total_tokens': 96})
# ...
